# %% [markdown]
# ### Values and Types
#
# A **value** is a basic unit of data. Every value in Python belongs to a Type that defines what the computer can do with it.
#
# ### The "Big Four" Basic Types:
# - Integer (int): Whole numbers without decimals (1, 2, -90).
# - Float (float): Numbers with a decimal point (3.4, -2.1).
# - Boolean (bool): Logic values: True or False.
# - String (str): Text wrapped in quotes ("Hello", 'Python').
#
# #### What is a Variable?
#
# A **variable** is a name that refers to a value. When you assign a value to a variable, Python stores it in memory so you can use it later.
#
# Variables are containers for storing data values.
#
# #### Syntax
#
# ```python
# variable_name = value
# ```

# %% [markdown]
# ### Creating Variables
# Python has no command for declaring a variable.
#
# A variable is created the moment you first assign a value to it.

# %%
name = 'Melody'
y = 5
x = 4.2
is_student = True

# %%
print(name)
print(x)
print(y)
print(is_student)
# Out:
# Melody
# 4.2
# 5
# True

# %%
name = 'Melody'
y = 5
x = 4.2
is_student = True

# %% [markdown]
# ### tththt

# %%
print(f"Name: {name}, y: {5}, x: {x}, is_student: {is_student}")
# Out:
# Name: Melody, y: 5, x: 4.2, is_student: True

# %%
 # Example using f-strings for formatted output
name = "Melody"
age = 30
height = 1.85
is_student = True
# print("Name: ", name, "Age: ", age, "Height: ", height) 
print(f"Name: {name}, Age: {age}, Height: {height}")
# Out:
# Name: Melody, Age: 30, Height: 1.85

# %% [markdown]
# In the example above:
# - name stores a string
# - age stores an integer
# - height stores a float
# - is_student stores a boolean

# %% [markdown]
# Variables do not need to be declared with any particular type, and can even change type after they have been set.

# %%
z = 4.2      # x is of type int
x = "Melody" # x is now of type str
y = 17
print(y)
# Out:
# 17

# %% [markdown]
# ### Get the Type
# You can get the data type of a variable with the `type()` function.

# %%
print(type(name))
print(type(x))
print(type(y))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# ## Type Conversion (Casting)
# Often, data is not in the format you need (e.g., a number might be stored as a string). Python provides functions to **cast** data from one type to another.
#
# | Function | Purpose | Example | Result |
# | :--- | :--- | :--- | :--- |
# | `int()` | Converts to Integer | `int("42")` | `42` |
# | `int()` | **Truncates** Decimals | `int(3.99)` | `3` (Does not round!) |
# | `float()` | Converts to Float | `float(10)` | `10.0` |
# | `str()` | Converts to String | `str(3.14)` | `"3.14"` |

# %%
x = int("3")
type(x)
# Out:
# int

# %%
score = 9.9
print(int(score))

# %% [markdown]
# ### Case-Sensitive
# Variable names are case-sensitive.

# %%
x = 4
X = 56
print(X)
# Out:
# 56

# %%
a = 'Mercy'
print(a)
# Out:
# Mercy

# %% [markdown]
# ### Python - Variable Names
#
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# Rules for Python variables:
#
# - A variable name must start with a letter or the underscore character
# - A variable name cannot start with a number
# - A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# - Variable names are case-sensitive (age, Age and AGE are three different variables)
# - A variable name cannot be any of the Python keywords.

# %% [markdown]
# #### Legal variable names

# %%
myVar = "Melody"
my_Var = "Emmilio"
_my_Var = 5
myVar2 = 67
MYVAY= 6890

# %% [markdown]
# #### Illegal variable names

# %%
# 76name = "Melody"
# name@ = "Melody"
class = 'Advanced Theoretical Zymurgy'
# Out:
#   Cell In[32], line 3
#     class = 'Advanced Theoretical Zymurgy'
#           ^
# SyntaxError: invalid syntax

# %%
76trombones = 'big parade'  # SyntaxError: invalid syntax
more@ = 1000000             # SyntaxError: invalid syntax
class = 'Advanced Theoretical Zymurgy'  # SyntaxError: invalid syntax
# Out:
#   Cell In[39], line 1
#
#     76trombones = 'big parade'  # SyntaxError: invalid syntax
#
#      ^
#
# SyntaxError: invalid decimal literal

# %% [markdown]
# 76trombones is illegal because it begins with a number. more@ is illegal because it contains an illegal character (@). But class is a keyword in Python, which means the interpreter uses it to recognize the structure of the program. Keywords cannot be used as variable names.
#
# Python reserves 35 keywords:

# %%
and     continue  finally  is        raise
as      def       for      lambda    return
assert  del       from     None      True
async   elif      global   nonlocal  try
await   else      if       not       while
break   except    import   or        with
class   False     in       pass      yield
# The above keywords are reserved in Python and cannot be used as variable names.
# Out:
# Running cells with 'myenv (Python 3.13.3)' requires the ipykernel package.
#
#
#
# Install 'ipykernel' into the Python environment.
#
#
#
# Command: 'c:/Users/user/Desktop/python_basics/myenv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ### Built-in Data Types
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:
#
# | **Category** | **Data Type** | **Example** | **Description** |
# |---------------|----------------|--------------|------------------|
# | **Numeric** | `int` | `x = 10` | Whole numbers |
# |  | `float` | `y = 10.5` | Decimal numbers |
# |  | `complex` | `z = 3 + 2j` | Complex numbers |
# | **String** | `str` | `"Hello"` | Text data |
# | **Boolean** | `bool` | `True`, `False` | Logical values |
# | **Sequence** | `list` | `[1, 2, 3]` | Ordered, changeable |
# |  | `tuple` | `(1, 2, 3)` | Ordered, unchangeable |
# |  | `range` | `range(5)` | Sequence of numbers |
# | **Set** | `set` | `{1, 2, 3}` | Unordered, unique items |
# | **Mapping** | `dict` | `{"name": "Melody"}` | Key-value pairs |

# %% [markdown]
# ### Operators in Python
#
# **Operators** in Python are special symbols or keywords that are used to perform operations on values and variables.
#
# Python supports several types of operators:
#
# ---
#
# #### 1. Arithmetic Operators
#
# Used for basic math operations:
#
# | Operator | Description        | Example     | Result |
# |----------|--------------------|-------------|--------|
# | `+`      | Addition            | `3 + 2`     | `5`    |
# | `-`      | Subtraction         | `5 - 2`     | `3`    |
# | `*`      | Multiplication      | `4 * 2`     | `8`    |
# | `/`      | Division            | `10 / 2`    | `5.0`  |
# | `//`     | Floor Division      | `7 // 2`    | `3`    |
# | `%`      | Modulus (remainder) | `7 % 2`     | `1`    |
# | `**`     | Exponentiation      | `2 ** 3`    | `8`    |

# %%
x = 10 
y = 3

sum = x + y
difference = x - y
quotient = x / y
floor_division = x // y
exponential = x ** y

# %%
print(sum)
print(difference)
print(quotient)
print(floor_division)
print(difference)
print(exponential)
# Out:
# 13
# 7
# 3.3333333333333335
# 3
# 7
# 1000

# %% [markdown]
# #### 2. Comparison Operators
#
# Used to compare values (result is `True` or `False`):
#
# | Operator | Description      | Example     | Result    |
# |----------|------------------|-------------|-----------|
# | `==`     | Equal to         | `5 == 5`    | `True`    |
# | `!=`     | Not equal to     | `5 != 3`    | `True`    |
# | `>`      | Greater than     | `5 > 3`     | `True`    |
# | `<`      | Less than        | `3 < 5`     | `True`    |
# | `>=`     | Greater or equal | `5 >= 5`    | `True`    |
# | `<=`     | Less or equal    | `3 <= 5`    | `True`    |

# %%
a = 5
b = 10

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# #### 3. Logical Operators
#
# Used to combine boolean expressions:
#
# | Operator | Description      | Example               | Result    |
# |----------|------------------|------------------------|-----------|
# | `and`    | True if both are True | `True and False` | `False`   |
# | `or`     | True if at least one is True | `True or False` | `True` |
# | `not`    | Reverses the result  | `not True`          | `False`   |

# %%
# using logical operators
x = 5 
print(x > 3 and x < 10)
print(x > 3 or x < 4)
print(not (x > 3 and x < 10))
# Out:
# True
# True
# False

# %% [markdown]
# #### 4. Assignment Operators
#
# Used to assign values to variables:
#
# | Operator | Example     | Same as        |
# |----------|-------------|----------------|
# | `=`      | `x = 5`     | `x = 5`        |
# | `+=`     | `x += 3`    | `x = x + 3`    |
# | `-=`     | `x -= 2`    | `x = x - 2`    |
# | `*=`     | `x *= 4`    | `x = x * 4`    |
# | `/=`     | `x /= 2`    | `x = x / 2`    |

# %%
x = 6
x = "Melody"
print(x)
# Out:
# Melody

# %%
x = 5
x += 3
print(x)
# Out:
# 8

# %%
# Examples using Assignment operators
x = 5
# x += 3
# x -= 2
# x *= 4
x /= 6
print(x)
# Out:
# 0.8333333333333334

# %% [markdown]
# ### Order of Operations
# When more than one operator appears in an expression, the order of evaluation depends on the rules of precedence. For mathematical operators, Python follows standard mathematical conventions.

# %%
result = 2 + 3 * 4
print(result)
# Out:
# 14

# %% [markdown]
# - Even though + comes first left-to-right, * has higher precedence, so 3 * 4 is evaluated before adding 2

# %% [markdown]
# | Precedence    | Operators                          | Description                                      |
# | ------------- | ---------------------------------- | ------------------------------------------------ |
# | 1 (highest)   | `()`                               | Parentheses                                      |
# | 2             | `**`                               | Exponentiation (right-to-left)                   |
# | 3             | `+x`, `-x`, `~x`                   | Unary plus, minus, bitwise NOT                   |
# | 4             | `*`, `/`, `//`, `%`                | Multiplication, Division, Floor Division, Modulo |
# | 5             | `+`, `-`                           | Addition, Subtraction                            |
# | 6             | `<<`, `>>`                         | Bitwise shifts                                   |
# | 7             | `&`                                | Bitwise AND                                      |
# | 8             | `^`                                | Bitwise XOR                                      |
# | 9             | `|`                                | Bitwise OR                                       |
# | 10            | `<`, `<=`, `>`, `>=`, `!=`, `==`   | Comparison operators (chained left-to-right)     |
# | 11            | `not x`                            | Logical NOT                                      |
# | 12            | `and`                              | Logical AND                                      |
# | 13            | `or`                               | Logical OR                                       |
# | 14            | `x if condition else y`            | Conditional (ternary) expression                 |
# | 15 (lowest)   | `lambda args: expression`          | Lambda function                                  |

# %% [markdown]
# ### Expressions in Python
#
# An **expression** in Python is a combination of **values**, **variables**, **operators**, and **function calls** that Python can **evaluate** to produce a result.
#
# In simple terms, an expression is **anything that results in a value**.
#
# #### Examples of Expressions
#
# ```python
# 2 + 3         # Arithmetic expression → 5
# a * b         # Uses variables and operator
# "Hello" + " World"  # String expression → "Hello World"
# len("Python")       # Function call expression → 6
# ```

# %% [markdown]
# Types of Expressions
#
# Arithmetic expressions:

# %%
results = 10 + 5 *2 
results
# Out:
# 20

# %% [markdown]
# String expressions: Combine or manipulate text

# %%
greetings = "Hi, " + "my name " + "is " + "Melody"
greetings
# Out:
# 'Hi, my name is Melody'

# %% [markdown]
# Boolean expressions: Return True or False

# %%
age = 12
is_adult = age >= 18
is_adult
# Out:
# False

# %% [markdown]
# ### Asking the User for Input in Python
#
# Often, programs need to interact with users by asking for information. In Python, you can prompt the user and read their response using the built-in `input()` function.
#
# ---
#
# #### 1. Basic `input()` Syntax
#
# ```python
# user_response = input(prompt_text)
# ```
#
# - prompt_text: A string that is displayed to the user (e.g., "Enter your name: ").
# - Return value: Always a string containing what the user typed (excluding the newline).

# %%
name = input("Enter your age: ")
print(f"Your age is: , {age}")
print(type(age))
# Out:
# Your age is: , 12
# <class 'int'>

# %% [markdown]
# #### Converting Input to Other Types
# Since ```input()``` always returns a string, you must convert (cast) it if you need a number or other type.
#
# a) Converting to Integer

# %%
age_str = int(input("Enter your age: "))
# age = int(age_str)

print(f"In the next 5 years, you will be {age_str + 5} years old.")
# Out:
# In the next 5 years, you will be 30 years old.

# %% [markdown]
# b) Converting to Float

# %%
price = float(input("Enter the price: "))
print(f"The price with the tax is: {price *0.10 + price}")
# Out:
# The price with the tax is: 220.0

# %% [markdown]
# ## Example
# **Scenario:** You have a user inputting their age as a string `"25"`. You need to calculate how many years they have until they turn 100.

# %%
age  = int(input("Enter your age: "))
years_left = 100 - age
print("Year lefts", years_left)
# Out:
# Year lefts 80

# %%
anything = input()
print("You typed: ", anything)
# Out:
# You typed:  I love python

# %%
age_input = input("Enter your age: ")
# 1. Convert the string to an integer
age = int(age_input)

# 2. Perform the math
years_left = 100 - age

# 3. Print the result by converting it back to a string
print("You have " + str(years_left) + " years left!")
# Out:
# You have 75 years left!

# %% [markdown]
# #### Prompting with No Text
# You can call input() without any prompt text; Python will wait silently for the user to type something and press Enter:

# %%
anything = input()
print("You typed:", anything)
# Out:
# You typed: melody
