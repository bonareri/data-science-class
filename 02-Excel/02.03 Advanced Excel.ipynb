# %% [markdown]
# ### VLOOKUP in Excel
#
# VLOOKUP (Vertical LOOK‑UP) searches the left‑most column of a table for a value, travels down that column, then returns a value from a column you specify in the same row.
#
# ```excel
# =VLOOKUP(lookup_value, table_array, col_index_num, [range_lookup])
# ```
#
# | Argument         | Meaning                                                    | Example value |
# | ---------------- | ---------------------------------------------------------- | ------------- |
# | `lookup_value`   | The value you’re searching for                             | `E2`          |
# | `table_array`    | The entire lookup table (must include the lookup column)   | `$A$2:$D$10`  |
# | `col_index_num`  | The column **number** (1 = left‑most) whose value you want | `4`           |
# | `[range_lookup]` | `FALSE` = **exact** match, `TRUE` = approximate (optional) | `FALSE`       |

# %% [markdown]
# ### INDEX MATCH
#
# The INDEX MATCH[1] Formula is the combination of two functions in Excel: INDEX[2] and MATCH[3].
#
# =INDEX() returns the value of a cell in a table based on the column and row number.
#
# =MATCH() returns the position of a cell in a row or column.
#
# Combined, the two formulas can look up and return the value of a cell in a table based on vertical and horizontal criteria.
#
# #### Why Use INDEX MATCH Instead of VLOOKUP?
#
# - Can look left of lookup column
# - No need to count columns
# - Faster with large datasets
# - Dynamic column/row lookup
#
# Syntax
# ```excel
# INDEX(array, row_num, [column_num])
# ```
# Returns the value from a table based on row and column positions.
#
# ```excel
# MATCH(lookup_value, lookup_array, [match_type])
# ```
# Returns the position (number) of a value in a range.
#
# Combined Formula: INDEX(MATCH)
# ```excel
# =INDEX(return_range, MATCH(lookup_value, lookup_range, 0))
# ```

# %% [markdown]
# # Introduction to Excel Power Query
#
# **Power Query** is a powerful data connection technology that enables users to **discover, connect, transform, and load (ETL)** data from various sources into Microsoft Excel. It simplifies data preparation, allowing users to clean, shape, and combine data without extensive coding.
#
# ---
#
# ## Why Use Power Query?
#
# Power Query is beneficial for:
#
# ✅ **Data Automation** – Saves time by automating data import and transformation
# ✅ **Data Cleaning & Shaping** – Helps remove duplicates, filter data, and split or merge columns
# ✅ **Data Integration** – Combines multiple data sources into a structured format
# ✅ **No Coding Required** – Uses an intuitive interface instead of complex formulas or VBA
#
# ---
#
# ## Key Features of Power Query
#
# ### 1️⃣ Data Importing
#
# Power Query can pull data from various sources, including:
#
# - Excel files
# - CSV and text files
# - Databases (SQL Server, MySQL, Oracle, etc.)
# - Web pages and APIs
#
# ---
#
# ### 2️⃣ Data Transformation
#
# Once data is imported, Power Query provides tools to:
#
# - Remove or filter rows
# - Split or merge columns
# - Change data types
# - Fill missing values
# - Pivot and unpivot data
#
# ---
#
# ### 3️⃣ Data Merging & Appending
#
# Power Query allows users to:
#
# - **Merge Queries** (Join data like SQL joins)
# - **Append Queries** (Stack similar tables together)
#
# ---
#
# ### 4️⃣ Automating Data Refresh
#
# With Power Query, once you set up transformations, you can **refresh the data automatically** whenever the source updates, eliminating manual work.
#
# ---
#
# ## Example: Loading and Cleaning Data Using Power Query
#
# 1. **Open Excel** → Go to **Data** tab → Click **Get & Transform Data** → Select **Get Data**
# 2. Choose your data source (e.g., Excel file, CSV, database)
# 3. Load the data into **Power Query Editor**
# 4. Apply transformations (remove duplicates, filter data, format columns)
# 5. Click **Close & Load** to bring cleaned data into Excel
#
# ---
#
# ## Conclusion
#
# **Power Query** is an essential tool for anyone working with large datasets in Excel. It simplifies data preparation, improves efficiency, and allows seamless integration of different data sources. Whether you’re an analyst, accountant, or business professional, **mastering Power Query can significantly enhance your data workflow**.
#
# ---
#
# > Would you like a step-by-step guide on a specific task in Power Query? 🚀
