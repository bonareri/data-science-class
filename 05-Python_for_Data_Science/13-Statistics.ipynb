# %%
import numpy as np

# Example data: students' exam scores
scores = [80, 90, 70, 85, 75]

# Mean, median, mode, standard deviation
mean_score = np.mean(scores)
median_score = np.median(scores)
std_deviation = np.std(scores)

print(f"Mean: {mean_score}, Median: {median_score}, Standard Deviation: {std_deviation}")
# Out:
# Mean: 80.0, Median: 80.0, Standard Deviation: 7.0710678118654755

# %% [markdown]
# | Feature     | Subquery                  | CTE                              |
# | ----------- | ------------------------- | -------------------------------- |
# | Readability | Can get messy when nested | Cleaner and structured           |
# | Reusability | Not reusable              | Can be referenced multiple times |
# | Debugging   | Harder                    | Easier                           |
# | Recursion   | Not supported             | Supported (recursive CTEs)       |
# | Performance | Same in most cases        | Same in most cases               |
