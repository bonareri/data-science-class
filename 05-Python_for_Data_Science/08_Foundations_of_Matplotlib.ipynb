# %% [markdown]
# ### Matplotlib Foundations
#
# `Matplotlib` is a powerful Python library for data visualization. It allows you to create a variety of static, animated, and interactive plots.
#
# Matplotlib is a multi-platform data visualization library built on NumPy arrays, and designed to work with the broader SciPy stack.
#
# It was conceived by John Hunter in 2002, originally as a patch to IPython for enabling interactive MATLAB-style plotting via gnuplot from the IPython command line.
#
# #### Why Use Matplotlib?
# - To visualize patterns, trends, and relationships in data
# - Works well with NumPy and Pandas
# - Highly customizable (colors, labels, legends, etc.)
# - Great for exploratory data analysis (EDA)

# %% [markdown]
# #### Basic Components of a Plot
# No matter which library you use, most plots involve:
#
# | Element         | Description                                        |
# | --------------- | -------------------------------------------------- |
# | `x-axis`        | Horizontal axis — usually the independent variable |
# | `y-axis`        | Vertical axis — usually the dependent variable     |
# | `data`          | What you're visualizing (numbers, categories)      |
# | `labels`        | Axis titles, legend, and chart title               |
# | `markers/lines` | How the data is drawn (dots, bars, lines, etc.)    |

# %% [markdown]
# #### What Are Variables in Data?
# In a dataset or experiment, a `variable` is anything you measure or observe — like age, income, temperature, or test scores.
#
# ##### Independent vs Dependent Variables
#
# | **Type**                    | **Definition**                                                                                   |
# | --------------------------- | ------------------------------------------------------------------------------------------------ |
# | **Independent Variable** | The variable you **change or control**. It causes a change in something else.                    |
# | **Dependent Variable**   | The variable you **measure or observe**. It changes **in response to** the independent variable. |

# %% [markdown]
# #### Real-World Examples
#
# | **Scenario**                                   | **Independent**         | **Dependent**            |
# | ---------------------------------------------- | ----------------------- | ------------------------ |
# | Studying hours vs. exam score                  | Hours studied           | Exam score               |
# | Temperature vs. ice cream sales                | Temperature             | Ice cream sales          |
# | Advertising budget vs. product sales           | Advertising spend       | Product sales            |
# | GDP per capita vs. Life expectancy (Gapminder) | GDP per capita (x-axis) | Life expectancy (y-axis) |

# %% [markdown]
# ##### In Plots:
# - The `independent` variable usually goes on the `x-axis` (horizontal)
# - The `dependent` variable usually goes on the `y-axis` (vertical)

# %% [markdown]
# ### General Matplotlib Tips
#
# Before we dive into the details of creating visualizations with Matplotlib, there are a few useful things you should know about using the package
#
# In Matplotlib:
#
# - Figure (fig) - the entire canvas (the whole page)
# - Axes (ax) - the actual plot area (where charts are drawn)
#
# Simple analogy:
#
# - fig = piece of paper
# - ax = the graph drawn on that paper

# %% [markdown]
# ### Create Your First Figure and Axes

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

ax.plot([1, 2, 3], [4, 5, 6])

ax.set_title('Simple Line Chart')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
plt.show()

# %% [markdown]
# ### Plot Something on the Axes

# %%
fig, ax = plt.subplots()

ax.plot([1, 2, 3], [4, 5, 6])

plt.show()

# %% [markdown]
# ### Add Labels and Title

# %%
fig, ax = plt.subplots()

ax.plot([1, 2, 3], [4, 5, 6])

ax.set_title("My First Plot")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")

plt.show()

# %% [markdown]
# ### Matplotlib with Superstore Dataset

# %%
import pandas as pd

df = pd.read_csv("Superstore (1).csv")

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     2.0  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     3.0  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     4.0  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     5.0  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   float64
#  1   Order ID       9800 non-null   str
#  2   Order Date     9800 non-null   str
#  3   Ship Date      9800 non-null   str
#  4   Ship Mode      9800 non-null   str
#  5   Customer ID    9800 non-null   str
#  6   Customer Name  9800 non-null   str
#  7   Segment        9800 non-null   str
#  8   Country        9800 non-null   str
#  9   City           9800 non-null   str
#  10  State          9800 non-null   str
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   str
#  13  Product ID     9800 non-null   str
#  14  Category       9800 non-null   str
#  15  Sub-Category   9800 non-null   str
#  16  Product Name   9800 non-null   str
#  17  Sales          9800 non-null   float64
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9789 entries, 0 to 9799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9789 non-null   float64
#  1   Order ID       9789 non-null   str
#  2   Order Date     9789 non-null   str
#  3   Ship Date      9789 non-null   str
#  4   Ship Mode      9789 non-null   str
#  5   Customer ID    9789 non-null   str
#  6   Customer Name  9789 non-null   str
#  7   Segment        9789 non-null   str
#  8   Country        9789 non-null   str
#  9   City           9789 non-null   str
#  10  State          9789 non-null   str
#  11  Postal Code    9789 non-null   float64
#  12  Region         9789 non-null   str
#  13  Product ID     9789 non-null   str
#  14  Category       9789 non-null   str
#  15  Sub-Category   9789 non-null   str
#  16  Product Name   9789 non-null   str
#  17  Sales          9789 non-null   float64
#  18  Quantity       9789 non-null   int64
# ...

# %%
# drop missing values
df.dropna(inplace=True)

# %% [markdown]
# ### Single Variable (Univariate)
#
# Bar Chart - Sales by Category

# %% [markdown]
# ##### MATLAB-style Interface
#
# When you use `plt`, you’re working on the current active plot implicitly.
#
# The MATLAB-style tools are contained in the pyplot (plt) interface.

# %%
sales_by_category = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)

sales_by_category.plot(kind = 'bar', color='green')

plt.title('Total Sales by Category')
plt.ylabel('Sales')
plt.xlabel('Category')

plt.xticks(rotation=45)

# plt.yticks(rotation=45)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Technology'),
#   Text(1, 0, 'Furniture'),
#   Text(2, 0, 'Office Supplies')])

# %% [markdown]
# This works fine because:
# - `pandas.plot()` internally creates and manages the figure/axes
# - `plt` applies changes to the `current axes`
#
# Limitation:
# - You don’t have an explicit reference to the axes
# - Harder to manage multiple subplots or complex figures

# %% [markdown]
# #### Object-Oriented style (ax)

# %%
sales_by_category

fig, ax = plt.subplots(figsize=(8, 6))

ax = sales_by_category.plot(kind='bar', color='orange')

ax.set_title('Total Sales by Category', fontsize=16, fontweight='bold')
ax.set_xlabel('Category', fontsize=12)
ax.set_ylabel('Sales', fontsize=12  )

plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Technology'),
#   Text(1, 0, 'Furniture'),
#   Text(2, 0, 'Office Supplies')])

# %% [markdown]
# Advantages:
# - You directly control that specific plot
# - Better for multiple charts
# - Cleaner and more professional

# %% [markdown]
# ### FORMATTING

# %%
# Aggregate data
sales_by_category = df.groupby('Category')['Sales'].sum()

# Create figure and axis
fig, ax = plt.subplots(figsize=(8, 5))

# Plot
sales_by_category.plot(kind='bar', ax=ax, color='steelblue', edgecolor='black')

# Title and labels (formatted properly)
ax.set_title('Total Sales by Category', fontsize=14, fontweight='bold')
ax.set_xlabel('Category', fontsize=12)
ax.set_ylabel('Total Sales', fontsize=12)

# Improve readability
ax.grid(axis='y', linestyle='--', alpha=0.6)
plt.xticks(rotation=45)

# Remove top/right borders (clean look)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sales by Segment - Pie Chart

# %%
sales_by_segment = df.groupby('Segment')['Sales'].sum().sort_values(ascending=False)

total = sales_by_segment.sum()
percentages = (sales_by_segment / total) * 100

#build custom labels with percentages
labels = [f"{seg} ({pct}%)" for seg, pct in zip(sales_by_segment.index, percentages.round(1))]

sales_by_segment.plot(
    kind = 'pie',
    startangle = 90,
    labels = labels,
    colors = ["#c799ff",'#66b3ff','#99ff99']
)

plt.title('Sales Distribution by Segment')

plt.show()

# %% [markdown]
# ### Histogram  Distribution of Sales

# %%
plt.hist(df['Sales'], bins = 30)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### Top 10 Customers by Sales

# %%
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# Top 10 customers by sales
top_customers = df.groupby('Customer Name')['Sales'].sum().nlargest(10).sort_values(ascending=True)

#plot
ax = top_customers.plot(kind = 'barh', color=colors, edgecolor='black', figsize=(10, 6))
ax.set_title('Top 10 Customers by Sales')
ax.set_xlabel('Total Sales')

# Normalize sales for colormap
norm = mcolors.Normalize(vmin=top_customers.min(), vmax=top_customers.max())
colors = cm.Blues(norm(top_customers.values))

# Add labels on bars
for i, value in enumerate(top_customers):
    label = f"{value/1000:.0f}K"  # Format as thousands
    ax.text(value + top_customers.max() * 0.01, i, label, va='center')

plt.show()

# %%
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# Get top 10 customers
top_customers = df.groupby('Customer Name')['Sales'].sum().nlargest(10).sort_values(ascending=True)

# Normalize sales for colormap
norm = mcolors.Normalize(vmin=top_customers.min(), vmax=top_customers.max())
colors = cm.coolwarm(norm(top_customers.values))  # 'Coolwarm' colormap

# Plot
ax = top_customers.plot(kind='barh', color=colors)
ax.set_title('Top 10 Customers by Sales')
ax.set_xlabel('Sales')

plt.show()

# %% [markdown]
# ### Compare Variables (Bivariate)
# #### Scatter Plot - Sales vs Profit

# %%
category  = df['Category'].unique()

for cat in category:
    subset = df[df['Category'] == cat]
    plt.scatter(subset['Sales'], subset['Profit'], label=cat)

plt.legend(title='Category')
plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ### Add Categories (Color Encoding)

# %%
categories = df['Category'].unique()

for cat in categories:
    subset = df[df['Category'] == cat]
    plt.scatter(subset['Sales'], subset['Profit'], label=cat)

plt.legend()
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs Profit by Category')
plt.show()

# %% [markdown]
# ### Time Series
#
# #### Sales Over Time

# %% [markdown]
# #### Set Order Date as a DatetimeIndex

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9789 entries, 0 to 9799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9789 non-null   float64
#  1   Order ID       9789 non-null   str
#  2   Order Date     9789 non-null   str
#  3   Ship Date      9789 non-null   str
#  4   Ship Mode      9789 non-null   str
#  5   Customer ID    9789 non-null   str
#  6   Customer Name  9789 non-null   str
#  7   Segment        9789 non-null   str
#  8   Country        9789 non-null   str
#  9   City           9789 non-null   str
#  10  State          9789 non-null   str
#  11  Postal Code    9789 non-null   float64
#  12  Region         9789 non-null   str
#  13  Product ID     9789 non-null   str
#  14  Category       9789 non-null   str
#  15  Sub-Category   9789 non-null   str
#  16  Product Name   9789 non-null   str
#  17  Sales          9789 non-null   float64
#  18  Quantity       9789 non-null   int64
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'])
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\tools\datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# %%
sales_over_time = df.groupby('Order Date')['Sales'].sum()

plt.plot(sales_over_time)
plt.title('Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# #### Set Order Date as Index (for Resampling)

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1     2.0  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2     3.0  CA-2017-138688 2017-06-12  16/06/2017    Second Class    DV-13045
# 3     4.0  US-2016-108966 2016-10-11  18/10/2016  Standard Class    SO-20335
# 4     5.0  US-2016-108966 2016-10-11  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df = df.set_index('Order Date')
df.head()
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2017-11-08     1.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-11-08     2.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-06-12     3.0  CA-2017-138688  16/06/2017    Second Class    DV-13045
# 2016-10-11     4.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
# 2016-10-11     5.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
monthly_sales = df['Sales'].resample('ME').sum()
monthly_sales.plot(title='Monthly Sales', xlabel='Date', ylabel='Total Sales')
plt.show()

# %%
df = df.set_index('Order Date')

# %%
df.head()
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2017-11-08     1.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-11-08     2.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-06-12     3.0  CA-2017-138688  16/06/2017    Second Class    DV-13045
# 2016-10-11     4.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
# 2016-10-11     5.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %% [markdown]
# #### Resample Sales by Month and Plot

# %%
monthly_sales = df['Sales'].resample('ME').sum()
monthly_sales.plot(title="Monthly Sales Trend", figsize=(10,4))
# Out:
# <Axes: title={'center': 'Monthly Sales Trend'}, xlabel='Order Date'>

# %% [markdown]
# - `resample('M')`: Groups data by month
# - You can also try `Q` for quarterly, `Y` for yearly

# %% [markdown]
# #### Work with Timestamps
# A `Timestamp` represents a specific point in time.

# %%
df.head()
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2017-11-08     1.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-11-08     2.0  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-06-12     3.0  CA-2017-138688  16/06/2017    Second Class    DV-13045
# 2016-10-11     4.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
# 2016-10-11     5.0  US-2016-108966  18/10/2016  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
df.loc['11/10/2016']
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-10   266.0  CA-2016-155040  15/11/2016  Standard Class    AH-10210
# 2016-11-10  5006.0  CA-2016-158659  14/11/2016    Second Class    SC-20695
# 2016-11-10  5849.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5850.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5851.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5852.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5853.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  9552.0  CA-2016-147690  14/11/2016  Standard Class    SC-20020
#
#                 Customer Name      Segment        Country          City  \
# Order Date
# 2016-11-10         Alan Hwang     Consumer  United States     Brentwood
# 2016-11-10      Steve Chapman    Corporate  United States      Richmond
# ...

# %%
df.loc['11/10/2016'].head()
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-10   266.0  CA-2016-155040  15/11/2016  Standard Class    AH-10210
# 2016-11-10  5006.0  CA-2016-158659  14/11/2016    Second Class    SC-20695
# 2016-11-10  5849.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5850.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
# 2016-11-10  5851.0  CA-2016-121783  14/11/2016  Standard Class    PO-19180
#
#                 Customer Name      Segment        Country       City  \
# Order Date
# 2016-11-10         Alan Hwang     Consumer  United States  Brentwood
# 2016-11-10      Steve Chapman    Corporate  United States   Richmond
# 2016-11-10  Philisse Overcash  Home Office  United States  Roseville
# 2016-11-10  Philisse Overcash  Home Office  United States  Roseville
# 2016-11-10  Philisse Overcash  Home Office  United States  Roseville
#
#                  State  Postal Code   Region       Product ID  \
# ...

# %% [markdown]
# #### Work with Periods
# A `Period` is a span of time (e.g., month or quarter)

# %%
df['Order_Period'] = df.index.to_period('M')
monthly_sales = df.groupby('Order_Period')['Sales'].sum()
monthly_sales.plot(title="Monthly Sales")
# Out:
# <Axes: title={'center': 'Monthly Sales'}, xlabel='Order_Period'>

# %% [markdown]
# #### Work with Timedeltas (Delivery Time)
# A `Timedelta` is the time difference between two dates.

# %%
df['Delivery Days'] = (df['Ship Date'] - df.index).dt.days
print(df[['Ship Date', 'Delivery Days']].head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 df['Delivery Days'] = (df['Ship Date'] - df.index).dt.days
#       2 print(df[['Ship Date', 'Delivery Days']].head())
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# ...

# %%
df['Order Date'] = df.index

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
df['Delivery Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
print(df[['Order Date', 'Ship Date', 'Delivery Days']].head())
# Out:
#            Order Date  Ship Date  Delivery Days
# Order Date
# 2017-11-08 2017-11-08 2017-11-11              3
# 2017-11-08 2017-11-08 2017-11-11              3
# 2017-06-12 2017-06-12 2017-06-16              4
# 2016-10-11 2016-10-11 2016-10-18              7
# 2016-10-11 2016-10-11 2016-10-18              7

# %%
df.head()
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2017-11-08     1.0  CA-2017-152156 2017-11-11    Second Class    CG-12520
# 2017-11-08     2.0  CA-2017-152156 2017-11-11    Second Class    CG-12520
# 2017-06-12     3.0  CA-2017-138688 2017-06-16    Second Class    DV-13045
# 2016-10-11     4.0  US-2016-108966 2016-10-18  Standard Class    SO-20335
# 2016-10-11     5.0  US-2016-108966 2016-10-18  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-11-08      Claire Gute   Consumer  United States        Henderson
# 2017-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2016-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
df['Delivery_Days'] = (df['Ship Date'] - df.index).dt.days
print(df[['Ship Date', 'Delivery_Days']].head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df['Delivery_Days'] = (df['Ship Date'] - df.index).dt.days
#       2 print(df[['Ship Date', 'Delivery_Days']].head())
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\pandas\core\arraylike.py:198, in OpsMixin.__sub__(self, other)
#     196 @unpack_zerodim_and_defer("__sub__")
#     197 def __sub__(self, other):
# --> 198     return self._arith_method(other, operator.sub)
#
# ...

# %%
# Create a column from index 
df['Order_Date'] = df.index

# %%
# Ensure both columns are datetime
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
# Compute delivery time
df['Delivery_Days'] = (df['Ship Date'] - df['Order_Date']).dt.days

# %%
print(df[['Order_Date', 'Ship Date', 'Delivery_Days']].head())
# Out:
#            Order_Date  Ship Date  Delivery_Days
# Order Date
# 2017-11-08 2017-11-08 2017-11-11              3
# 2017-11-08 2017-11-08 2017-11-11              3
# 2017-06-12 2017-06-12 2017-06-16              4
# 2016-10-11 2016-10-11 2016-10-18              7
# 2016-10-11 2016-10-11 2016-10-18              7

# %% [markdown]
# ## Adding Interactivity

# %% [markdown]
# #### What is Plotly?
# `Plotly` is an open-source Python library used to create interactive and visually appealing data visualizations. It’s especially powerful for:
#
# - Exploratory data analysis (EDA)
# - Dashboards
# - Web-based visualizations
#
# Unlike static plots in Matplotlib or Seaborn, Plotly plots are fully interactive — you can zoom, hover, filter, and export directly from the chart.

# %% [markdown]
# #### Introduction to Plotly with Gapminder
#
# Setup & Imports
# Start with installing and importing Plotly:
#
# `pip install plotly`
#
# `pip install "nbformat>=4.2.0"`

# %%
import plotly.express as px
import nbformat
print(nbformat.__version__)
# Out:
# 5.10.4

# %% [markdown]
# #### Load the Dataset
# `Gapminder` comes built-in with Plotly Express.

# %% [markdown]
# - `px.data.gapminder()` is a sample dataset included with Plotly.
# - It contains global data by country, year, continent.

# %%
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   str
#  1   continent  1704 non-null   str
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   str
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), str(3)
# memory usage: 106.6 KB

# %%
df['country'].unique()
# Out:
# <StringArray>
# [       'Afghanistan',            'Albania',            'Algeria',
#              'Angola',          'Argentina',          'Australia',
#             'Austria',            'Bahrain',         'Bangladesh',
#             'Belgium',
#  ...
#              'Uganda',     'United Kingdom',      'United States',
#             'Uruguay',          'Venezuela',            'Vietnam',
#  'West Bank and Gaza',        'Yemen, Rep.',             'Zambia',
#            'Zimbabwe']
# Length: 142, dtype: str

# %%
df_east_africa = df[df['country'].isin(['Kenya', 'Uganda', 'Tanzania'])]
fig  = px.line(df_east_africa, x='year', y='gdpPercap', color='country',
                 title='GDP Per Capita Over Time in East Africa')
fig.show()

# %%
df_2007 = df[df['year'] == 2007]
fig = px.scatter(df_2007, x='gdpPercap', y='lifeExp', color='continent',
                 size='pop', hover_name='country', log_x=True,
                 title='GDP Per Capita vs Life Expectancy (2007)')
fig.show()

# %%
df_bar = df_2007.groupby('continent')['pop'].sum().reset_index().sort_values(by='pop', ascending=False)
fig = px.bar(df_bar, x='continent', y='pop', title='Population by Continent (2007)')
fig.show()

# %%
fig = px.box(df_2007, x='continent', y='lifeExp', points = 'all', 
             title='Life Expectancy by Continent (2007)')
fig.show()

# %%
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   str
#  1   continent  1704 non-null   str
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   str
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), str(3)
# memory usage: 106.6 KB

# %%
df['country'].unique()
# Out:
# <StringArray>
# [       'Afghanistan',            'Albania',            'Algeria',
#              'Angola',          'Argentina',          'Australia',
#             'Austria',            'Bahrain',         'Bangladesh',
#             'Belgium',
#  ...
#              'Uganda',     'United Kingdom',      'United States',
#             'Uruguay',          'Venezuela',            'Vietnam',
#  'West Bank and Gaza',        'Yemen, Rep.',             'Zambia',
#            'Zimbabwe']
# Length: 142, dtype: str

# %% [markdown]
# #### Line Chart — Life Expectancy Over Time

# %% [markdown]
# - `x='year'`: time on the horizontal axis.
# - `y='lifeExp'`: measured outcome (dependent variable).
# - `color='country'`: different lines for each country.

# %%
df_east_africa = df[df['country'].isin(['Kenya', 'Uganda', 'Tanzania'])]

fig = px.line(df_east_africa, x='year', y='lifeExp', color='country',
              title='Life Expectancy Over Time')
fig.show()

# %% [markdown]
# When you call:
#
# `fig.show()`
#
# Plotly uses its internal display engine (based on plotly.io) to render the figure as rich HTML/JavaScript inside the notebook output cell. This is what makes the chart interactive.
#
# To do this, Plotly relies on:
# - IPython (to display rich output)
# - `nbformat` (to properly format and render notebook MIME types like HTML)

# %% [markdown]
# #### Scatter Plot — Multivariate View
#
# visualize multiple variables at once.

# %%
df_2007 = df[df['year'] == 2007]

fig = px.scatter(df_2007, 
                 x='gdpPercap', y='lifeExp',
                 size='pop', color='continent',
                 hover_name='country', log_x=True,
                 title='GDP vs Life Expectancy (2007)')
fig.show()

# %% [markdown]
# - `x`: GDP per capita (independent variable)
# - `y`: Life expectancy (dependent variable)
# - `size`: population (adds a 3rd dimension)
# - `color`: continent (grouping)
# - `hover_name`: tooltip info (country)
# - `log_x=True`: fixes skewed GDP values

# %% [markdown]
# #### Bar Chart — Total Population by Continent
# Compare values across categories.

# %%
df_bar = df_2007.groupby('continent')['pop'].sum().reset_index().sort_values(by='pop', ascending=False)

fig = px.bar(df_bar, x='continent', y='pop',
             title='Total Population by Continent (2007)')
fig.show()

# %% [markdown]
# #### Box Plot — Life Expectancy Spread
# distribution across groups.

# %%
fig = px.box(df_2007, x='continent', y='lifeExp', points= "all", hover_name='country',
             title='Life Expectancy Distribution by Continent')
fig.show()

# %% [markdown]
# #### Choropleth Map — Global Life Expectancy
# ##### What is a Choropleth Map?
# A `Choropleth Map` is a thematic map where regions (countries, states, etc.) are colored or shaded based on the value of a numerical variable.
#
# Useful for:
#
# - Visualizing geographic patterns
# - Comparing values across locations
# - Displaying country-level or region-level statistics

# %%
fig  = px.choropleth(df_2007, 
                     locations= 'iso_alpha',
                     color='lifeExp',
                     hover_name='country',
                     projection='natural earth',
                     title='Life Expectancy by Country (2007)')
fig.show()

# %% [markdown]
# Parameters
#
# | Parameter                | Description                                                           |
# | ------------------------ | --------------------------------------------------------------------- |
# | `locations`              | Location ID (e.g., ISO codes like `"KEN"` for Kenya)                  |
# | `color`                  | The numeric column used to determine color intensity                  |
# | `hover_name`             | Column shown on hover                                                 |
# | `color_continuous_scale` | Color theme (e.g., `'Viridis'`, `'Blues'`, `'Plasma'`, `'Reds'`)      |
# | `projection`             | Map type (e.g., `"natural earth"`, `"equirectangular"`, `"mercator"`) |
# | `title`                  | Chart title                                                           |

# %%
country_sales = df.groupby('Country')['Sales'].sum().reset_index()

fig = px.choropleth(
    country_sales,
    locations='Country',
    locationmode='country names',
    color='Sales',
    title='Sales by Country'
)

fig.show()

# %% [markdown]
# #### Animated Scatter Plot — GDP vs Life Expectancy Over Time
# Show trends dynamically over time.

# %%
fig = px.scatter(df,
                 x = 'gdpPercap',
                 y = 'lifeExp',
                 animation_frame = 'year',
                 animation_group = 'country',
                 color = 'continent',
                 size = 'pop',
                 log_x = True,
                 hover_name = 'country',
                 size_max = 60,
                 range_y = [20, 90],
                 range_x = [100, 100000],
                 title='GDP vs Life Expectancy (All Years)'
                )
fig.show()

# %% [markdown]
# #### What is a Map Projection?
# A `projection` is a method used to transform the 3D surface of the Earth (a sphere or ellipsoid) into a 2D flat map.
#
# Since you can't perfectly flatten a globe, every projection has some distortion — in shape, size, distance, or direction.
#
# #### Why Projections Matter in Choropleth Maps
# When you use:
#
# `projection="natural earth"`
#
# You're telling Plotly how to `flatten` the Earth for your map display.
#
# Different projections emphasize different features:
#
# - Some keep area accurate (good for comparing regions)
# - Some preserve shapes (good for navigation)
# - Some minimize distortion near the equator or poles

# %% [markdown]
# Common Projections in Plotly
#
# | Projection Type          | Description                                                              |
# | ------------------------ | ------------------------------------------------------------------------ |
# | `"natural earth"`        | A **compromise projection** (balanced, aesthetically pleasing)           |
# | `"equirectangular"`      | Straightforward, but **distorts shape** at poles                         |
# | `"mercator"`             | Preserves angles; used in **Google Maps** but **greatly enlarges poles** |
# | `"orthographic"`         | Makes the Earth look like a **3D globe**                                 |
# | `"azimuthal equal area"` | Good for **preserving area**, often used in scientific maps              |
# | `"winkel tripel"`        | A modern compromise used by **National Geographic**                      |

# %% [markdown]
# #### Customizing Plots in Plotly (Using Plotly Express)
# Customizing plots helps you `communicate insights clearly` by improving how your charts look and feel.

# %% [markdown]
# ##### 1. Chart Title and Axis Labels
#
# Use the `title` argument for the chart title and` labels` to rename axes.

# %%
fig = px.scatter(df_2007, 
                 x="gdpPercap", 
                 y="lifeExp", 
                 title="Life Expectancy vs GDP (2007)",
                 labels={"gdpPercap": "GDP Per Capita (USD)", 
                         "lifeExp": "Life Expectancy (Years)"})
fig.show()

# %% [markdown]
# ##### 2. Themes and Templates
# Plotly comes with built-in themes you can apply with `template`.

# %%
fig.update_layout(template="plotly_dark")
